# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Here we chose the genomic regions in PBMC data for which we will infer correlations between expression and accessibility

# %%
from IPython import display
import pandas as pd
import numpy as np
import scipy
import scipy.stats

import pickle
from timeit import default_timer as timer
Folder = '/content/drive/MyDrive/'

# %%
cor_hum_tmp = pd.read_csv(Folder+'SCRaPL/Real/Results_atac_human_col/feature_cor_tmp.csv',',',header=[0])

# %%
cor_hum_tmp_tf = tf.convert_to_tensor(cor_hum_tmp)

# %%
ind = tf.where(abs(cor_hum_tmp_tf)>0.3616402) 
indices = pd.DataFrame(ind.numpy()+1)
indices.columns = ["peak_ind","gene_ind"]

# %%
indices.to_csv(Folder+'SCRaPL/Real/Results_atac_human_col/features_select_1.csv')
