# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# This script is used to perform inference on mEBC data.

# %%
from IPython import display
import pandas as pd
import numpy as np
import scipy
import scipy.stats

from matplotlib import pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from tensorflow import keras

from tensorflow.keras import layers
import tensorflow_probability as tfp
import tensorflow.compat.v2 as tf
tf.enable_v2_behavior()

import pickle
from timeit import default_timer as timer

# %%
tfd = tfp.distributions
tfb = tfp.bijectors
Folder = '/content/drive/MyDrive/'

# %%
#Load accessibility, expression data and cell normalization constants
yy_acc_pd = pd.read_csv(Folder+'SCRaPL/Real/Data/Acc_atac.csv',',',header=[0],index_col=[0])
yy_exp_pd = pd.read_csv(Folder+'SCRaPL/Real/Data/Rna_atac.csv',',',header=[0],index_col=[0])
Norm = pd.read_csv(Folder+'SCRaPL/Real/Data/Nrm_atac.csv',',',index_col=[1])
Norm = Norm.drop(columns=Norm.columns[0])

# %%
yy_acc = tf.convert_to_tensor(yy_acc_pd,dtype=tf.float32)
yy_exp = tf.convert_to_tensor(yy_exp_pd,dtype=tf.float32)
Norm_acc = tf.convert_to_tensor(Norm.iloc[:,0],dtype=tf.float32)
Norm_exp = tf.convert_to_tensor(Norm.iloc[:,1],dtype=tf.float32)

# %%
x_genes,x_cells = tf.shape(yy_acc)

# %%
aff = tfb.Chain([tfb.Shift(-1.),tfb.Scale(scale=2.)])
aff_inv = tfb.Invert(aff)

exp = tfb.Exp()
log = tfb.Invert(exp)

tanh = tfb.Tanh()
tanh_inv = tfb.Invert(tanh)

sigm = tfb.Sigmoid()
sigm_inv = tfb.Invert(sigm)

cor_trsf = tfb.Chain([aff_inv,tanh,tfb.Scale(scale=0.5)])
cor_trsf_inv = tfb.Invert(cor_trsf)

eps=0.001
bin_bij = tfb.Chain([tfb.Shift(eps/2.0),tfb.Scale(scale=1.0-eps),tfb.NormalCDF()])

cor_bij = tfb.Chain([tanh,tfb.Scale(scale=0.5)])
std_bij = tfb.Chain([exp,tfb.Scale(scale=-1.0)])
sqr_bij = tfb.Square()

# %%
#SCRaPL's graphical model
def SCRaPL(N_genes,N_cells,Nrm_acc,Nrm_rna):
    def prior():
        cor_lt = yield tfd.TransformedDistribution( distribution = tfd.Beta( concentration0 = 15.0*tf.ones([N_genes,1]), concentration1=15.0*tf.ones([N_genes,1])), bijector= cor_trsf_inv, name = "cor_lt" )
        m_acc_lt = yield tfd.Normal(loc=3*tf.ones([N_genes,1]),scale=tf.ones([N_genes,1]), name = "m_acc_lt")
        m_exp_lt = yield tfd.Normal(loc=4*tf.ones([N_genes,1]),scale=tf.ones([N_genes,1]), name = "m_exp_lt")
        s_acc_lt = yield tfd.TransformedDistribution( distribution = tfd.InverseGamma(concentration=2.5*tf.ones([N_genes,1]),scale=4.5*tf.ones([N_genes,1])),bijector= log, name = "s_acc_lt" )
        s_exp_lt = yield tfd.TransformedDistribution( distribution = tfd.InverseGamma(concentration=2.5*tf.ones([N_genes,1]),scale=4.5*tf.ones([N_genes,1])),bijector= log , name = "s_exp_lt")
        infl_acc_lt = yield tfd.TransformedDistribution( distribution = tfd.Beta( concentration0 =8.0*tf.ones([N_genes,1]), concentration1=2.0*tf.ones([N_genes,1])), bijector= sigm_inv, name = "infl_acc_lt" )
        infl_rna_lt = yield tfd.TransformedDistribution( distribution = tfd.Beta( concentration0 =8.0*tf.ones([N_genes,1]), concentration1=2.0*tf.ones([N_genes,1])), bijector= sigm_inv, name = "infl_rna_lt" )

        cor = cor_bij.forward(cor_lt)
        s_acc = std_bij.forward(s_acc_lt)
        s_exp = std_bij.forward(s_exp_lt)
        infl_acc = sigm.forward(infl_acc_lt)
        infl_rna = sigm.forward(infl_rna_lt)
        
        mm_acc = tf.math.multiply( m_acc_lt,tf.ones([N_genes,N_cells]))
        mm_exp = tf.math.multiply( m_exp_lt,tf.ones([N_genes,N_cells]))
        ss_acc = tf.math.multiply( s_acc   ,tf.ones([N_genes,N_cells]))
        ss_exp = tf.math.multiply( s_exp   ,tf.ones([N_genes,N_cells]))
        ccor =   tf.math.multiply( cor     ,tf.ones([N_genes,N_cells]))
        p_acc =  tf.math.multiply( infl_acc,tf.ones([N_genes,N_cells]))
        p_rna =  tf.math.multiply( infl_rna,tf.ones([N_genes,N_cells]))  

        nrm_acc = tf.math.multiply( log.forward(Nrm_acc),tf.ones([N_genes,1]))
        nrm_rna = tf.math.multiply( log.forward(Nrm_rna),tf.ones([N_genes,1]))

        x_acc = yield tfd.Normal(loc = mm_acc, scale = ss_acc,name="x_acc")
        m_cnd_exp = mm_exp+tf.math.multiply(tf.math.divide(tf.math.multiply(ss_exp,x_acc-mm_acc),ss_acc),ccor)
        s_cnd_exp = tf.math.sqrt(tf.math.multiply(1-tf.math.square(ccor),tf.math.square(ss_exp)))

        x_exp = yield tfd.Normal(loc = m_cnd_exp, scale = s_cnd_exp,name="x_exp")

        pp_acc = tf.stack([p_acc,1-p_acc],axis=-1)
        x_acc_lt = tf.stack([-20*tf.ones_like(x_acc),x_acc+nrm_acc],axis=-1)

        pp_rna = tf.stack([p_rna,1-p_rna],axis=-1)
        x_exp_lt = tf.stack([-20*tf.ones_like(x_exp),x_exp+nrm_rna],axis=-1)

        y_acc = yield tfd.MixtureSameFamily(
                                                          mixture_distribution = tfd.Categorical(probs=pp_acc),
                                                          components_distribution = tfd.Poisson(log_rate=x_acc_lt),
                                                          name="y_acc")
        y_exp = yield tfd.MixtureSameFamily(
                                                          mixture_distribution = tfd.Categorical(probs=pp_rna),
                                                          components_distribution = tfd.Poisson(log_rate=x_exp_lt),
                                                          name="y_exp")

    comp_var_coroutine = tfd.JointDistributionCoroutineAutoBatched(prior)
    return comp_var_coroutine

# %%
#As the dataset is too large to fit in memory we utilize genomic region independence assumption to perform sample chunks of 10 in each turn.
#This also makes it easier to tune parameters to target acceptance rate as the sampling space is reduced. Depending computational resources
#chunk size (www) has to be tuned  
prt = 1
time = []
skp_ind = []
www = 10
prts_tot = tf.math.ceil(x_genes/www)
jj = 0
while prt < prts_tot+1:
          aa =  (prt-1)*www
          aa1 = prt*www
          yy_acc_prt = yy_acc[aa:aa1,:]
          yy_exp_prt = yy_exp[aa:aa1,:]
          batch_ft = tf.shape(yy_exp_prt)[0]

          mdl_tr = SCRaPL(batch_ft,x_cells,Norm_acc,Norm_exp)
          init = mdl_tr.sample()
          vrr = [init[0],init[1],init[2],init[3],init[4],init[5],init[6],init[7],init[8]]

          unconstrained_bijectors = [tfb.Identity(),tfb.Identity(),tfb.Identity(),tfb.Identity(),tfb.Identity(),tfb.Identity(),tfb.Identity(),tfb.Identity(),tfb.Identity()]
          @tf.function(autograph=False, jit_compile=True) 

          def sample_nuts():

                  init_x = vrr
                  num_burnin_iter = 3000
                  num_warmup_iter = int(0.8*num_burnin_iter)
                  num_chain_iter = 2000

                  target_accept_rate = 0.65 

                  log_post = lambda x0,x1,x2,x3,x4,x5,x6,x7,x8: mdl_tr.log_prob(x0,x1,x2,x3,x4,x5,x6,x7,x8,yy_acc_prt,yy_exp_prt)

                  def trace_fn(_, pkr):
                        return (
                            pkr.inner_results.inner_results.target_log_prob,
                            pkr.inner_results.inner_results.leapfrogs_taken,
                            pkr.inner_results.inner_results.has_divergence,
                            pkr.inner_results.inner_results.energy,
                            pkr.inner_results.inner_results.log_accept_ratio,
                            pkr.inner_results.inner_results.step_size
                              )
                  nuts= tfp.mcmc.NoUTurnSampler(
                                            target_log_prob_fn=log_post,
                                            step_size=0.05,
                                            max_tree_depth=6
                                                ) 
                  ttk = tfp.mcmc.TransformedTransitionKernel(
                                            inner_kernel=nuts,
                                            bijector=unconstrained_bijectors
                                                                )
                  adapted_kernel=tfp.mcmc.DualAveragingStepSizeAdaptation(
                                            inner_kernel=ttk,
                                            num_adaptation_steps=num_warmup_iter,
                                            target_accept_prob= target_accept_rate)
                  
                  states , sampler_stat =tfp.mcmc.sample_chain(
                                    num_results=num_chain_iter,
                                    num_burnin_steps=num_burnin_iter,
                                    current_state=init_x,
                                    kernel=adapted_kernel,
                                    trace_fn=trace_fn) 

                  return states, sampler_stat

          start = timer()
          samples, sampler_stat = sample_nuts() 
          end = timer()
          ttime = end-start

          p_accept = tf.math.exp(tfp.math.reduce_logmeanexp(tf.minimum(sampler_stat[4], 0.)))
          stp_sz = sampler_stat[5][0]
          hmc_cor,hmc_m_acc,hmc_m_exp,hmc_s_acc,hmc_s_exp,hmc_inf_acc,hmc_inf_exp,hmc_x_acc,hmc_x_exp = samples

          crr_nuts = tf.squeeze(hmc_cor)
          s_exp_nuts = tf.squeeze(hmc_s_exp)
          s_acc_nuts = tf.squeeze(hmc_s_acc)
          m_acc_nuts = tf.squeeze(hmc_m_acc)
          m_exp_nuts = tf.squeeze(hmc_m_exp)

          qc_acc_rt = tf.math.logical_and(p_accept<0.9,p_accept>0.4)
          qc_stp_sz = stp_sz>0.00001

          if tf.math.logical_and(qc_acc_rt,qc_stp_sz)== True:
                time.append(ttime)
                with open(Folder+'SCRaPL/Real/Results_atac/nuts_cor_atac_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(crr_nuts, handle)
                with open(Folder+'SCRaPL/Real/Results_atac/nuts_m_acc_atac_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(m_acc_nuts, handle)
                with open(Folder+'SCRaPL/Real/Results_atac/nuts_m_exp_atac_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(m_exp_nuts, handle)

                with open(Folder+'SCRaPL/Real/Results_atac/nuts_s_acc_atac_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(s_acc_nuts, handle)
                with open(Folder+'SCRaPL/Real/Results_atac/nuts_s_exp_atac_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(s_exp_nuts, handle)

                with open(Folder+'SCRaPL/Real/Results_atac/nuts_inf_acc_atac_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(tf.squeeze(hmc_inf_acc), handle)
                with open(Folder+'SCRaPL/Real/Results_atac/nuts_inf_exp_atac_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(tf.squeeze(hmc_inf_exp), handle)
                    
                #with open(Folder+'SCRaPL/Synth/Results/'+ref+'/nuts_x_met_'+ref+'_'+str(prt)+'.pickle', 'wb') as handle:
                #    pickle.dump(tf.squeeze(hmc_x_met), handle)
                #with open(Folder+'SCRaPL/Synth/Results/'+ref+'/nuts_x_exp_'+ref+'_'+str(prt)+'.pickle', 'wb') as handle:
                #    pickle.dump(tf.squeeze(hmc_x_exp), handle)
                
                avg_time = tf.reduce_mean(tf.stack(time))
                rem_time = (tf.cast(prts_tot,dtype=tf.float32)-tf.cast(prt,dtype=tf.float32)) *avg_time
                print(tf.squeeze([rem_time,prt,stp_sz,p_accept]),tf.math.logical_and(qc_acc_rt,qc_stp_sz))
                prt+=1
          else:
                time.append(ttime)
                
                if jj>3.0:
                    skp_ind.append(prt)
                    prt+=1
                    jj=0.0

                avg_time = tf.reduce_mean(tf.stack(time))
                rem_time = (tf.cast(prts_tot,dtype=tf.float32)-tf.cast(prt,dtype=tf.float32)) *avg_time
                print(tf.squeeze([rem_time,prt,stp_sz,p_accept]),tf.math.logical_and(qc_acc_rt,qc_stp_sz))
                jj+=1
# Out:
# tf.Tensor([1.0886926e+04 3.5900000e+02 8.0633061e-03 6.8388450e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([1.0730267e+04 3.6000000e+02 8.2667479e-03 6.7425239e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([1.0560628e+04 3.6100000e+02 7.6442417e-03 7.0190972e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([1.0406953e+04 3.6200000e+02 8.1858253e-03 6.8347728e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# WARNING:tensorflow:5 out of the last 5 calls to <function sample_nuts at 0x7faf161808c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# tf.Tensor([1.0242203e+04 3.6300000e+02 8.4028868e-03 6.6760540e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# WARNING:tensorflow:6 out of the last 6 calls to <function sample_nuts at 0x7fae2bce7c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# tf.Tensor([1.0086623e+04 3.6400000e+02 8.5915616e-03 6.4899009e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([9.9185391e+03 3.6500000e+02 8.5222032e-03 6.6136855e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([9.7670869e+03 3.6600000e+02 8.3770100e-03 6.8522084e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([9.596418e+03 3.670000e+02 8.246189e-03 6.844241e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([9.425153e+03 3.680000e+02 7.901460e-03 6.774151e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([9.258572e+03 3.690000e+02 8.473816e-03 6.719300e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([9.0936357e+03 3.7000000e+02 7.8061283e-05 6.4483875e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([8.9268672e+03 3.7100000e+02 8.3902981e-03 6.8244535e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([8.7591562e+03 3.7200000e+02 8.4009152e-03 6.5992385e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([8.5916201e+03 3.7300000e+02 8.9578098e-03 6.5494317e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([8.4209785e+03 3.7400000e+02 2.3305326e-04 6.4949936e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([8.2543398e+03 3.7500000e+02 8.3314860e-03 6.4402103e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([8.0856602e+03 3.7600000e+02 8.5594300e-03 6.6703904e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([7.9263408e+03 3.7700000e+02 8.3079329e-03 6.7786103e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([7.7638506e+03 3.7800000e+02 8.4205344e-03 6.6313124e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([7.6014644e+03 3.7900000e+02 8.6354772e-03 6.8056631e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([7.438414e+03 3.800000e+02 7.531821e-03 7.096430e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([7.2776938e+03 3.8100000e+02 8.1288330e-03 6.8238604e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([7.1155127e+03 3.8200000e+02 8.4918113e-03 6.7237777e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([6.9529395e+03 3.8300000e+02 8.7632798e-03 6.5615135e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([6.7858467e+03 3.8400000e+02 8.7370193e-03 6.5698385e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([6.619053e+03 3.850000e+02 8.839166e-03 6.554562e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([6.4513423e+03 3.8600000e+02 8.5817687e-03 6.6374528e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([6.2851353e+03 3.8700000e+02 8.3712563e-03 6.8782431e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([6.1119316e+03 3.8800000e+02 8.2934657e-03 6.8057477e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([5.944963e+03 3.890000e+02 8.330338e-03 6.746779e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([5.779904e+03 3.900000e+02 8.157186e-03 6.751916e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([5.6146504e+03 3.9100000e+02 8.3246436e-03 6.6472650e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([5.4487905e+03 3.9200000e+02 7.3278868e-03 6.9810683e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([5.2818921e+03 3.9300000e+02 8.1559997e-03 6.6838485e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([5.1155801e+03 3.9400000e+02 8.2080066e-03 6.8821406e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([4.9497695e+03 3.9500000e+02 8.7928399e-03 6.6127205e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([4.783559e+03 3.960000e+02 8.238242e-03 6.657368e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([4.6183984e+03 3.9700000e+02 8.5676378e-03 6.6584164e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([4.4531768e+03 3.9800000e+02 8.6897332e-03 6.6016465e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([4.288438e+03 3.990000e+02 7.944187e-03 6.816826e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([4.1228306e+03 4.0000000e+02 8.2156258e-03 6.6827267e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([3.9575718e+03 4.0100000e+02 8.4483298e-03 6.5813482e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([3.7925254e+03 4.0200000e+02 8.5037854e-03 6.4643347e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([3.6268948e+03 4.0300000e+02 8.1790164e-03 6.3231635e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([3.4616084e+03 4.0400000e+02 8.1563620e-03 6.7516875e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([3.2969358e+03 4.0500000e+02 8.2392087e-03 6.7600852e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([3.1322498e+03 4.0600000e+02 8.6882412e-03 6.6407007e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([2.9669214e+03 4.0700000e+02 8.4409006e-03 6.5577596e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([2.801503e+03 4.080000e+02 8.521382e-03 6.670053e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([2.6364583e+03 4.0900000e+02 8.5332021e-03 6.8307072e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([2.4718435e+03 4.1000000e+02 8.0669206e-03 6.4157569e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([2.3071414e+03 4.1100000e+02 8.2972152e-03 6.7391527e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([2.1402368e+03 4.1200000e+02 1.8854591e-04 6.3401043e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([1.9759424e+03 4.1300000e+02 8.6731166e-03 6.7427909e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([1.8110602e+03 4.1400000e+02 8.8335359e-03 6.6954499e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([1.6459978e+03 4.1500000e+02 8.3019845e-03 6.7469150e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([1.4813442e+03 4.1600000e+02 8.7280534e-03 6.6560096e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([1.3163374e+03 4.1700000e+02 8.5241618e-03 6.6058564e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([1.1517045e+03 4.1800000e+02 8.1909439e-03 6.7352784e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([9.870781e+02 4.190000e+02 8.885413e-03 6.486371e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([8.2241431e+02 4.2000000e+02 7.2680777e-03 6.7741346e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([6.5788354e+02 4.2100000e+02 8.4817233e-03 6.5243399e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([4.933537e+02 4.220000e+02 8.220925e-03 6.520962e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([3.2894116e+02 4.2300000e+02 8.5038226e-03 6.7739022e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([1.6446114e+02 4.2400000e+02 9.0242019e-03 6.5749115e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor([0.0000000e+00 4.2500000e+02 8.5357130e-03 6.7700046e-01], shape=(4,), dtype=float32) tf.Tensor(True, shape=(), dtype=bool)
