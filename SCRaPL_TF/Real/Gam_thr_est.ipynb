# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# The script is used ot estimate γ from eqution (9) of the main script.

# %%
from IPython import display
import pandas as pd
import numpy as np
import scipy
import scipy.stats

from matplotlib import pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from tensorflow import keras
from sklearn.neighbors import KernelDensity

from tensorflow.keras import layers
import tensorflow_probability as tfp
import tensorflow.compat.v2 as tf
tf.enable_v2_behavior()

import pickle
from timeit import default_timer as timer
Folder = '/content/drive/MyDrive/'

# %%
#Load posterior correlation samples from negative control data.
#with open(Folder+'SCRaPL/Real/Results_atac_neg_col/nuts_cor_atac_ninf_neg1.pickle', 'rb') as handle:
#with open(Folder+'SCRaPL/Real/Results_col_neg/nuts_cor_gastr_neg3.pickle', 'rb') as handle:
with open(Folder+'SCRaPL/Real/Results_col_neg/nuts_cor_gastr_NT_neg5.pickle', 'rb') as handle:
    cor_nuts = pickle.load(handle)

# %%
#Set γ to be the 90th percent qunatile of posterior correlation in absolute terms.  
smps,gns = tf.shape(cor_nuts)
col_smps = tf.reshape(cor_nuts,shape=(smps*gns))
gam = tfp.stats.quantiles(tf.math.abs(tf.math.tanh(col_smps/2)),num_quantiles=10,interpolation='linear')[-2]

# %%
print(gam)
# Out:
# tf.Tensor(0.28205222, shape=(), dtype=float32)
# tf.Tensor(
# [7.4505806e-09 2.1958556e-02 4.4285219e-02 6.7321211e-02 9.1560520e-02
#  1.1758096e-01 1.4652424e-01 1.7989802e-01 2.2153121e-01 2.8205222e-01
#  7.8152400e-01], shape=(11,), dtype=float32)
