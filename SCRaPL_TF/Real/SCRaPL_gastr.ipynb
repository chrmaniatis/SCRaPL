# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# This script is used to perform inference on mESC data.

# %%
from IPython import display
import pandas as pd
import numpy as np
import scipy
import scipy.stats

from matplotlib import pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from tensorflow import keras

from tensorflow.keras import layers
import tensorflow_probability as tfp
import tensorflow.compat.v2 as tf
tf.enable_v2_behavior()

import pickle
from timeit import default_timer as timer
Folder = '/content/drive/MyDrive/'

# %%
tfd = tfp.distributions
tfb = tfp.bijectors

# %%
#Load methylation, expression data and cell normalization constants
yy_met = pd.read_csv(Folder+'SCRaPL/Real/Data/Met.csv',sep=',',index_col=[0])
yy_exp = pd.read_csv(Folder+'SCRaPL/Real/Data/Rna.csv',sep=',',index_col=[0])
CpG = pd.read_csv(Folder+'SCRaPL/Real/Data/CpG.csv',sep=',',index_col=[0])
nrm = pd.read_csv(Folder+'SCRaPL/Real/Data/nrm.csv',sep=',',index_col=[1])

# %%
Norm = tf.transpose(tf.convert_to_tensor(nrm,dtype=tf.float32))
yy_met = tf.convert_to_tensor(yy_met,dtype=tf.float32)
CpG = tf.convert_to_tensor(CpG,dtype=tf.float32)
yy_exp = tf.convert_to_tensor(yy_exp,dtype=tf.float32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-683dd444b59b> in <module>()
# ----> 1 Norm = tf.transpose(tf.convert_to_tensor(nrm,dtype=tf.float32))
#       2 yy_met = tf.convert_to_tensor(yy_met,dtype=tf.float32)
#       3 CpG = tf.convert_to_tensor(CpG,dtype=tf.float32)
#       4 yy_exp = tf.convert_to_tensor(yy_exp,dtype=tf.float32)
#
# NameError: name 'tf' is not defined

# %%
x_genes,x_cells = tf.shape(CpG)

# %%
aff = tfb.Chain([tfb.Shift(-1.),tfb.Scale(scale=2.)])
aff_inv = tfb.Invert(aff)

exp = tfb.Exp()
log = tfb.Invert(exp)

tanh = tfb.Tanh()
tanh_inv = tfb.Invert(tanh)

sigm = tfb.Sigmoid()
sigm_inv = tfb.Invert(sigm)

cor_trsf = tfb.Chain([aff_inv,tanh,tfb.Scale(scale=0.5)])
cor_trsf_inv = tfb.Invert(cor_trsf)

eps=0.001
bin_bij = tfb.Chain([tfb.Shift(eps/2.0),tfb.Scale(scale=1.0-eps),tfb.NormalCDF()])

cor_bij = tfb.Chain([tanh,tfb.Scale(scale=0.5)])
std_bij = tfb.Chain([exp,tfb.Scale(scale=-1.0)])
sqr_bij = tfb.Square()

# %%
#SCRaPL's graphical model
def SCRaPL(N_genes,N_cells,Cover,Nrm):
    def prior():
        cor_lt = yield tfd.TransformedDistribution( distribution = tfd.Beta( concentration0 = 15.0*tf.ones([N_genes,1]), concentration1=15.0*tf.ones([N_genes,1])), bijector= cor_trsf_inv, name = "cor_lt" )
        m_met_lt = yield tfd.Normal(loc=0*tf.ones([N_genes,1]),scale=tf.ones([N_genes,1]), name = "m_met_lt")
        m_exp_lt = yield tfd.Normal(loc=4*tf.ones([N_genes,1]),scale=tf.ones([N_genes,1]), name = "m_exp_lt")
        s_met_lt = yield tfd.TransformedDistribution( distribution = tfd.InverseGamma(concentration=2.5*tf.ones([N_genes,1]),scale=4.5*tf.ones([N_genes,1])),bijector= log, name = "s_met_lt" )
        s_exp_lt = yield tfd.TransformedDistribution( distribution = tfd.InverseGamma(concentration=2.5*tf.ones([N_genes,1]),scale=4.5*tf.ones([N_genes,1])),bijector= log , name = "s_exp_lt")
        infl_lt = yield tfd.TransformedDistribution( distribution = tfd.Beta( concentration0 =8.0*tf.ones([N_genes,1]), concentration1=2.0*tf.ones([N_genes,1])), bijector= sigm_inv, name = "infl_lt" )

        cor = cor_bij.forward(cor_lt)
        s_met = std_bij.forward(s_met_lt)
        s_exp = std_bij.forward(s_exp_lt)
        infl = sigm.forward(infl_lt)
        
        mm_met = tf.math.multiply( m_met_lt,tf.ones([N_genes,N_cells]))
        mm_exp = tf.math.multiply( m_exp_lt,tf.ones([N_genes,N_cells]))
        ss_met = tf.math.multiply( s_met   ,tf.ones([N_genes,N_cells]))
        ss_exp = tf.math.multiply( s_exp   ,tf.ones([N_genes,N_cells]))
        ccor =   tf.math.multiply( cor     ,tf.ones([N_genes,N_cells]))
        p =      tf.math.multiply( infl    ,tf.ones([N_genes,N_cells]))  
        nrm = tf.math.multiply( log.forward(Nrm),tf.ones([N_genes,1]))

        x_met = yield tfd.Normal(loc = mm_met, scale = ss_met,name="x_met")
        m_cnd_exp = mm_exp+tf.math.multiply(tf.math.divide(tf.math.multiply(ss_exp,x_met-mm_met),ss_met),ccor)
        s_cnd_exp = tf.math.sqrt(tf.math.multiply(1-tf.math.square(ccor),tf.math.square(ss_exp)))

        x_exp = yield tfd.Normal(loc = m_cnd_exp, scale = s_cnd_exp,name="x_exp")

        rt_bin = bin_bij.forward(x_met)

        pp = tf.stack([p,1-p],axis=-1)
        x_exp_msk= tf.where(tf.equal(Cover, 0), -20*tf.ones_like(x_exp),x_exp)
        x_exp_lt = tf.stack([-20*tf.ones_like(x_exp),x_exp_msk+nrm],axis=-1)

        y_met = yield tfd.Binomial(total_count=Cover,probs=rt_bin,name="y_met")
        y_exp = yield tfd.MixtureSameFamily(
                                            mixture_distribution = tfd.Categorical(probs=pp),
                                            components_distribution = tfd.Poisson(log_rate=x_exp_lt),
                                            name="y_exp")

    comp_var_coroutine = tfd.JointDistributionCoroutineAutoBatched(prior)
    return comp_var_coroutine

# %%
#As the dataset is too large to fit in memory we utilize genomic region independence assumption to perform sample chunks of 60 in each turn.
#This also makes it easier to tune parameters to target acceptance rate as the sampling space is reduced. Depending computational resources
#chunk size (www) has to be tuned  
prt = 1
time = []
www = 60
prts_tot = tf.math.ceil(x_genes/www)
jj = 0

while prt < prts_tot+1:
          aa =  (prt-1)*www
          aa1 = prt*www
          yy_met_prt = yy_met[aa:aa1,:]
          yy_exp_prt = yy_exp[aa:aa1,:]
          CpG_prt = CpG[aa:aa1,:]

          batch_num = tf.shape(CpG_prt)[0]

          mdl_tr = SCRaPL(batch_num,x_cells,CpG_prt,Norm)
          init = mdl_tr.sample()
          vrr = [init[0],init[1],init[2],init[3],init[4],init[5],init[6],init[7]]

          unconstrained_bijectors = [tfb.Identity(),tfb.Identity(),tfb.Identity(),tfb.Identity(),tfb.Identity(),tfb.Identity(),tfb.Identity(),tfb.Identity()]
          @tf.function(autograph=False, jit_compile=True) 

          def sample_nuts():

            init_x = vrr
            num_burnin_iter = 3000
            num_warmup_iter = int(0.8*num_burnin_iter)
            num_chain_iter = 2000

            target_accept_rate = 0.65 

            log_post = lambda x0,x1,x2,x3,x4,x5,x6,x7: mdl_tr.log_prob(x0,x1,x2,x3,x4,x5,x6,x7,yy_met_prt,yy_exp_prt)

            def trace_fn(_, pkr):
                  return (
                      pkr.inner_results.inner_results.target_log_prob,
                      pkr.inner_results.inner_results.leapfrogs_taken,
                      pkr.inner_results.inner_results.has_divergence,
                      pkr.inner_results.inner_results.energy,
                      pkr.inner_results.inner_results.log_accept_ratio,
                      pkr.inner_results.inner_results.step_size
                        )
            nuts= tfp.mcmc.NoUTurnSampler(
                                      target_log_prob_fn=log_post,
                                      step_size=0.05,
                                      max_tree_depth=6
                                          ) 
            ttk = tfp.mcmc.TransformedTransitionKernel(
                                      inner_kernel=nuts,
                                      bijector=unconstrained_bijectors
                                                          )
            adapted_kernel=tfp.mcmc.DualAveragingStepSizeAdaptation(
                                      inner_kernel=ttk,
                                      num_adaptation_steps=num_warmup_iter,
                                      target_accept_prob= target_accept_rate)
            
            states , sampler_stat =tfp.mcmc.sample_chain(
                              num_results=num_chain_iter,
                              num_burnin_steps=num_burnin_iter,
                              current_state=init_x,
                              kernel=adapted_kernel,
                              trace_fn=trace_fn) 

            return states, sampler_stat

          start = timer()
          samples, sampler_stat = sample_nuts() 
          end = timer()
          ttime = end-start

          p_accept = tf.math.exp(tfp.math.reduce_logmeanexp(tf.minimum(sampler_stat[4], 0.)))
          stp_sz = sampler_stat[5][0]

          hmc_cor,hmc_m_met,hmc_m_exp,hmc_s_met,hmc_s_exp,hmc_inf,hmc_x_met,hmc_x_exp = samples

          crr_nuts = tf.squeeze(hmc_cor)
          s_exp_nuts = tf.squeeze(hmc_s_exp)
          s_met_nuts = tf.squeeze(hmc_s_met)
          m_met_nuts = tf.squeeze(hmc_m_met)
          m_exp_nuts = tf.squeeze(hmc_m_exp)

          qc_acc_rt = tf.math.logical_and(p_accept<0.9,p_accept>0.4)
          qc_stp_sz = stp_sz>0.00001

          if tf.math.logical_and(qc_acc_rt,qc_stp_sz)== True:
                time.append(ttime)
                with open(Folder+'SCRaPL/Real/Results/nuts_cor_gastr_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(crr_nuts, handle)
                with open(Folder+'SCRaPL/Real/Results/nuts_m_met_gastr_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(m_met_nuts, handle)
                with open(Folder+'SCRaPL/Real/Results/nuts_m_exp_gastr_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(m_exp_nuts, handle)

                with open(Folder+'SCRaPL/Real/Results/nuts_s_met_gastr_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(s_met_nuts, handle)
                with open(Folder+'SCRaPL/Real/Results/nuts_s_exp_gastr_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(s_exp_nuts, handle)

                with open(Folder+'SCRaPL/Real/Results/nuts_inf_gastr_'+str(prt)+'.pickle', 'wb') as handle:
                    pickle.dump(tf.squeeze(hmc_inf), handle)

                #with open(Folder+'SCRaPL/Synth/Results/'+ref+'/nuts_x_met_'+ref+'_'+str(prt)+'.pickle', 'wb') as handle:
                #    pickle.dump(tf.squeeze(hmc_x_met), handle)
                #with open(Folder+'SCRaPL/Synth/Results/'+ref+'/nuts_x_exp_'+ref+'_'+str(prt)+'.pickle', 'wb') as handle:
                #    pickle.dump(tf.squeeze(hmc_x_exp), handle)
                
                avg_time = tf.reduce_mean(tf.stack(time))
                rem_time = (tf.cast(prts_tot,dtype=tf.float32)-tf.cast(prt,dtype=tf.float32)) *avg_time
                print(rem_time,prt,stp_sz,qc_acc_rt,tf.math.logical_and(qc_acc_rt,qc_stp_sz))
                prt+=1
          else:
                time.append(ttime)
                
                if jj>2.0:
                    skp_ind.append(prt)
                    prt+=1
                    jj=0.0

                avg_time = tf.reduce_mean(tf.stack(time))
                rem_time = (tf.cast(prts_tot,dtype=tf.float32)-tf.cast(prt,dtype=tf.float32)) *avg_time
                print(rem_time,prt,stp_sz,qc_acc_rt,tf.math.logical_and(qc_acc_rt,qc_stp_sz))
                jj+=1
# Out:
# tf.Tensor(8629.137, shape=(), dtype=float32) 106 tf.Tensor(0.0058744345, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(8429.094, shape=(), dtype=float32) 107 tf.Tensor(0.009240231, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(8267.924, shape=(), dtype=float32) 108 tf.Tensor(0.009743118, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(8096.169, shape=(), dtype=float32) 109 tf.Tensor(0.010031606, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# WARNING:tensorflow:5 out of the last 5 calls to <function sample_nuts at 0x7fd4f143a440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# tf.Tensor(7934.923, shape=(), dtype=float32) 110 tf.Tensor(0.00933435, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# WARNING:tensorflow:6 out of the last 6 calls to <function sample_nuts at 0x7fd47f6dba70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# tf.Tensor(7761.606, shape=(), dtype=float32) 111 tf.Tensor(0.010374323, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(7597.921, shape=(), dtype=float32) 112 tf.Tensor(0.01076458, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(7433.9355, shape=(), dtype=float32) 113 tf.Tensor(0.011903322, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(7213.841, shape=(), dtype=float32) 114 tf.Tensor(0.009694713, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(7058.0522, shape=(), dtype=float32) 115 tf.Tensor(0.010474553, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(6901.1187, shape=(), dtype=float32) 116 tf.Tensor(0.010058483, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(6739.141, shape=(), dtype=float32) 117 tf.Tensor(0.009115433, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(6573.99, shape=(), dtype=float32) 118 tf.Tensor(0.007406237, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(6414.1904, shape=(), dtype=float32) 119 tf.Tensor(0.010661073, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(6251.2607, shape=(), dtype=float32) 120 tf.Tensor(0.010911935, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(6082.575, shape=(), dtype=float32) 121 tf.Tensor(0.0095635895, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(5919.179, shape=(), dtype=float32) 122 tf.Tensor(0.009030706, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(5757.3867, shape=(), dtype=float32) 123 tf.Tensor(0.008930413, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(5586.7393, shape=(), dtype=float32) 124 tf.Tensor(0.008010764, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(5423.254, shape=(), dtype=float32) 125 tf.Tensor(0.008486287, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(5260.3086, shape=(), dtype=float32) 126 tf.Tensor(0.008708029, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(5089.91, shape=(), dtype=float32) 127 tf.Tensor(0.0095714, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(4926.4844, shape=(), dtype=float32) 128 tf.Tensor(0.009795165, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(4763.4277, shape=(), dtype=float32) 129 tf.Tensor(0.010813104, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(4600.6265, shape=(), dtype=float32) 130 tf.Tensor(0.010005719, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(4436.61, shape=(), dtype=float32) 131 tf.Tensor(0.01113792, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(4272.8735, shape=(), dtype=float32) 132 tf.Tensor(0.008651398, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(4107.747, shape=(), dtype=float32) 133 tf.Tensor(0.0076226094, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(3942.4883, shape=(), dtype=float32) 134 tf.Tensor(0.009754967, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(3766.2651, shape=(), dtype=float32) 135 tf.Tensor(0.007836714, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(3604.455, shape=(), dtype=float32) 136 tf.Tensor(0.009139614, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(3440.9707, shape=(), dtype=float32) 137 tf.Tensor(0.00863527, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(3272.709, shape=(), dtype=float32) 138 tf.Tensor(0.0009088312, shape=(), dtype=float32) tf.Tensor(False, shape=(), dtype=bool) tf.Tensor(False, shape=(), dtype=bool)
# tf.Tensor(3272.7832, shape=(), dtype=float32) 138 tf.Tensor(0.009098745, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(3109.545, shape=(), dtype=float32) 139 tf.Tensor(0.005283596, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(2946.006, shape=(), dtype=float32) 140 tf.Tensor(0.009932674, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(2783.159, shape=(), dtype=float32) 141 tf.Tensor(0.005875488, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(2620.211, shape=(), dtype=float32) 142 tf.Tensor(0.008263363, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(2456.8184, shape=(), dtype=float32) 143 tf.Tensor(0.00917669, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(2293.3933, shape=(), dtype=float32) 144 tf.Tensor(0.008307541, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(2130.2139, shape=(), dtype=float32) 145 tf.Tensor(0.009330839, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(1966.4048, shape=(), dtype=float32) 146 tf.Tensor(0.0050997077, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(1802.647, shape=(), dtype=float32) 147 tf.Tensor(0.010530653, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(1639.3007, shape=(), dtype=float32) 148 tf.Tensor(0.0065631773, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(1475.447, shape=(), dtype=float32) 149 tf.Tensor(0.006735589, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(1311.3262, shape=(), dtype=float32) 150 tf.Tensor(0.008182203, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(1147.5723, shape=(), dtype=float32) 151 tf.Tensor(0.0074914214, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(983.67755, shape=(), dtype=float32) 152 tf.Tensor(0.0077055404, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(819.7351, shape=(), dtype=float32) 153 tf.Tensor(0.0093382895, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(655.7392, shape=(), dtype=float32) 154 tf.Tensor(0.0104888035, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(491.65582, shape=(), dtype=float32) 155 tf.Tensor(0.007730913, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(327.84357, shape=(), dtype=float32) 156 tf.Tensor(0.008353886, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(163.95195, shape=(), dtype=float32) 157 tf.Tensor(0.008128318, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
# tf.Tensor(0.0, shape=(), dtype=float32) 158 tf.Tensor(0.008175387, shape=(), dtype=float32) tf.Tensor(True, shape=(), dtype=bool) tf.Tensor(True, shape=(), dtype=bool)
