# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# This script is used to aggregate samples from different chunks of mESC data when SCRaPL is fitted without inflation.

# %%
from IPython import display
import pandas as pd
import numpy as np
import scipy
import scipy.stats

from matplotlib import pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from tensorflow import keras

from tensorflow.keras import layers
import tensorflow_probability as tfp
import tensorflow.compat.v2 as tf
tf.enable_v2_behavior()

import pickle
from timeit import default_timer as timer
Folder = '/content/drive/MyDrive/'

# %%
#For each one of the chunks store parameters of interest in a list.
cor_nuts_col = []
s_met_nuts_col = []
s_exp_nuts_col = []
m_met_nuts_col = []
m_exp_nuts_col = []
m_exp_nuts_col = []
inf_nuts_col = []
llk_nuts_col = []
x_exp_mn_nuts_col = []
x_met_mn_nuts_col = []

for prt in range(316):
    with open(Folder+'SCRaPL/Real/Results_DIC/nuts_cor_gastr_ninf_'+str(prt+1)+'.pickle', 'rb') as handle:
        cor_nuts_col.append(pickle.load(handle))
    with open(Folder+'SCRaPL/Real/Results_DIC/nuts_s_met_gastr_ninf_'+str(prt+1)+'.pickle', 'rb') as handle:
        s_met_nuts_col.append(pickle.load(handle))
    with open(Folder+'SCRaPL/Real/Results_DIC/nuts_s_exp_gastr_ninf_'+str(prt+1)+'.pickle', 'rb') as handle:
        s_exp_nuts_col.append(pickle.load(handle))
    with open(Folder+'SCRaPL/Real/Results_DIC/nuts_m_met_gastr_ninf_'+str(prt+1)+'.pickle', 'rb') as handle:
        m_met_nuts_col.append(pickle.load(handle))
    with open(Folder+'SCRaPL/Real/Results_DIC/nuts_m_exp_gastr_ninf_'+str(prt+1)+'.pickle', 'rb') as handle:
        m_exp_nuts_col.append(pickle.load(handle))
    with open(Folder+'SCRaPL/Real/Results_DIC/log_prob_gastr_ninf_'+str(prt+1)+'.pickle', 'rb') as handle:
        llk_nuts_col.append(pickle.load(handle))
    with open(Folder+'SCRaPL/Real/Results_DIC/avg_exp_ninf_gastr_'+str(prt+1)+'.pickle', 'rb') as handle:
        x_exp_mn_nuts_col.append(pickle.load(handle))
    with open(Folder+'SCRaPL/Real/Results_DIC/avg_met_ninf_gastr_'+str(prt+1)+'.pickle', 'rb') as handle:
        x_met_mn_nuts_col.append(pickle.load(handle))

    print(prt/316)
# Out:
# 0.0
# 0.0031645569620253164
# 0.006329113924050633
# 0.00949367088607595
# 0.012658227848101266
# 0.015822784810126583
# 0.0189873417721519
# 0.022151898734177215
# 0.02531645569620253
# 0.028481012658227847
# 0.03164556962025317
# 0.03481012658227848
# 0.0379746835443038
# 0.04113924050632911
# 0.04430379746835443
# 0.04746835443037975
# 0.05063291139240506
# 0.05379746835443038
# 0.056962025316455694
# 0.060126582278481014
# 0.06329113924050633
# 0.06645569620253164
# 0.06962025316455696
# 0.07278481012658228
# 0.0759493670886076
# 0.07911392405063292
# 0.08227848101265822
# 0.08544303797468354
# 0.08860759493670886
# 0.09177215189873418
# 0.0949367088607595
# 0.0981012658227848
# 0.10126582278481013
# 0.10443037974683544
# 0.10759493670886076
# 0.11075949367088607
# 0.11392405063291139
# 0.11708860759493671
# 0.12025316455696203
# 0.12341772151898735
# 0.12658227848101267
# 0.12974683544303797
# 0.13291139240506328
# 0.1360759493670886
# 0.13924050632911392
# 0.14240506329113925
# ...

# %%
#Concat all lists to aggregate all samples.
cor_nuts = tf.concat(cor_nuts_col,axis=-1)
s_met_nuts = tf.concat(s_met_nuts_col,axis=-1)
s_exp_nuts = tf.concat(s_exp_nuts_col,axis=-1)
m_met_nuts = tf.concat(m_met_nuts_col,axis=-1)
m_exp_nuts = tf.concat(m_exp_nuts_col,axis=-1)
llk_nuts = tf.concat(llk_nuts_col,axis=-1)
x_exp_mn_nuts = tf.concat(x_exp_mn_nuts_col,axis=-2)
x_met_mn_nuts = tf.concat(x_met_mn_nuts_col,axis=-2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8267f6f982d2> in <module>()
# ----> 1 cor_nuts = tf.concat(cor_nuts_col,axis=-1)
#       2 s_met_nuts = tf.concat(s_met_nuts_col,axis=-1)
#       3 s_exp_nuts = tf.concat(s_exp_nuts_col,axis=-1)
#       4 m_met_nuts = tf.concat(m_met_nuts_col,axis=-1)
#       5 m_exp_nuts = tf.concat(m_exp_nuts_col,axis=-1)
#
# NameError: name 'tf' is not defined

# %%
#Save parameters of interest.
with open(Folder+'SCRaPL/Real/Results_DIC_col/nuts_cor_gastr_ninf_dic.pickle', 'wb') as handle:
    pickle.dump(cor_nuts, handle)
with open(Folder+'SCRaPL/Real/Results_DIC_col/nuts_m_met_gastr_ninf_dic.pickle', 'wb') as handle:
    pickle.dump(m_met_nuts, handle)
with open(Folder+'SCRaPL/Real/Results_DIC_col/nuts_m_exp_gastr_ninf_dic.pickle', 'wb') as handle:
    pickle.dump(m_exp_nuts, handle)
with open(Folder+'SCRaPL/Real/Results_DIC_col/nuts_s_met_gastr_ninf_dic.pickle', 'wb') as handle:
    pickle.dump(s_met_nuts, handle)
with open(Folder+'SCRaPL/Real/Results_DIC_col/nuts_s_exp_gastr_ninf_dic.pickle', 'wb') as handle:
    pickle.dump(s_exp_nuts, handle)
with open(Folder+'SCRaPL/Real/Results_DIC_col/nuts_llk_gastr_ninf_dic.pickle', 'wb') as handle:
    pickle.dump(llk_nuts, handle)
with open(Folder+'SCRaPL/Real/Results_DIC_col/nuts_x_met_mn_avg_ninf_dic.pickle', 'wb') as handle:
    pickle.dump(x_met_mn_nuts, handle)
with open(Folder+'SCRaPL/Real/Results_DIC_col/nuts_x_exp_mn_avg_ninf_dic.pickle', 'wb') as handle:
    pickle.dump(x_exp_mn_nuts, handle)
